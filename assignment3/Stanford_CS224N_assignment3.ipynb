# %% [markdown]
# ### Q1. Implement a window-based classifier model in q1_window.py using this approach.
#
# To do so, you will have to:
#
#     i. (4 points) Transform a batch of input sequences into a batch of windowed input-output pairs in the make windowed data function. You can test your implementation by running python q1 window.py test1.
#
#     ii. (6 points) Implement the feed-forward model described above by appropriately completing functions and the variable n window features in the WindowModel class. You can test your implementation by running python q1 window.py test2.
#
#     iii. (3 points) Complete the training loop in method NERModel.fit (ner model.py). The training and validation datasets are already divided, and the outer loop for training multi- ple epochs is also written. You need to examine the function minibatches (utils.py) and Model.train on batch (which NERModel inherits from) and write the training procedure that loops over all minibatches in the dataset.
#
#     iv. (2 points) Train your model using the command python q1 window.py train. The code should take only about 2–3 minutes to run and you should get a development score of at least 81% F1.

# %%
#q1_window.py Q1.i

# !python q1_window.py test1
# Out:
# /Users/KunWuYao/anaconda/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing make_windowed_data
# INFO:Passed!

# %%
#q1_window.py Q1.ii
# !python q1_window.py test2
# Out:
# /Users/KunWuYao/anaconda/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Testing implementation of WindowModel
# INFO:Loading training data...
# INFO:Done. Read 721 sentences
# INFO:Loading dev data...
# INFO:Done. Read 721 sentences
# INFO:Built dictionary for 2653 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 3.24 seconds
# 2018-04-19 03:41:14.318723: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 10
# 5/5 [==============================] - 0s - train loss: 1.0227
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	274.00 	2.00   	36.00  	0.00   	512.00
# ORG    	78.00  	0.00   	7.00   	2.00   	304.00
# LOC    	43.00  	0.00   	170.00 	0.00   	364.00
# MISC   	11.00  	0.00   	4.00   	3.00   	240.00
# O      	18.00  	2.00   	10.00  	14.00  	7072.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.92 	0.65 	0.33 	0.44
# ORG  	0.00 	0.00 	0.00 	0.00
# LOC  	0.95 	0.75 	0.29 	0.42
# MISC 	0.97 	0.16 	0.01 	0.02
# O    	0.84 	0.83 	0.99 	0.91
# micro	0.93 	0.82 	0.82 	0.82
# macro	0.74 	0.48 	0.33 	0.36
# not-O	0.95 	0.66 	0.22 	0.33
#
# INFO:Entity level P/R/F1: 0.31/0.14/0.19
#
# INFO:Epoch 2 out of 10
# 5/5 [==============================] - 0s - train loss: 0.5843
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	598.00 	0.00   	36.00  	0.00   	190.00
# ORG    	161.00 	0.00   	25.00  	1.00   	204.00
# LOC    	96.00  	0.00   	226.00 	0.00   	255.00
# MISC   	69.00  	0.00   	15.00  	0.00   	174.00
# O      	78.00  	2.00   	37.00  	1.00   	6998.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.93 	0.60 	0.73 	0.65
# ORG  	0.00 	0.00 	0.00 	0.00
# LOC  	0.95 	0.67 	0.39 	0.49
# MISC 	0.00 	0.00 	0.00 	0.00
# O    	0.90 	0.89 	0.98 	0.94
# micro	0.94 	0.85 	0.85 	0.85
# macro	0.56 	0.43 	0.42 	0.42
# not-O	0.95 	0.61 	0.40 	0.49
#
# INFO:Entity level P/R/F1: 0.51/0.33/0.40
#
# INFO:Epoch 3 out of 10
# 5/5 [==============================] - 0s - train loss: 0.4876
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	687.00 	0.00   	60.00  	0.00   	77.00
# ORG    	214.00 	2.00   	71.00  	0.00   	104.00
# LOC    	95.00  	1.00   	386.00 	0.00   	95.00
# MISC   	90.00  	0.00   	103.00 	0.00   	65.00
# O      	129.00 	2.00   	167.00 	0.00   	6818.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.93 	0.57 	0.83 	0.67
# ORG  	0.96 	0.40 	0.01 	0.01
# LOC  	0.94 	0.49 	0.67 	0.57
# MISC 	0.00 	0.00 	0.00 	0.00
# O    	0.93 	0.95 	0.96 	0.96
# micro	0.94 	0.86 	0.86 	0.86
# macro	0.75 	0.48 	0.49 	0.44
# not-O	0.95 	0.54 	0.52 	0.53
#
# INFO:Entity level P/R/F1: 0.48/0.48/0.48
#
# INFO:Epoch 4 out of 10
# 5/5 [==============================] - 0s - train loss: 0.4330
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	709.00 	12.00  	49.00  	0.00   	54.00
# ORG    	169.00 	60.00  	63.00  	1.00   	98.00
# LOC    	79.00  	24.00  	403.00 	0.00   	71.00
# MISC   	76.00  	18.00  	88.00  	13.00  	63.00
# O      	117.00 	24.00  	116.00 	0.00   	6859.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.94 	0.62 	0.86 	0.72
# ORG  	0.96 	0.43 	0.15 	0.23
# LOC  	0.95 	0.56 	0.70 	0.62
# MISC 	0.97 	0.93 	0.05 	0.10
# O    	0.94 	0.96 	0.96 	0.96
# micro	0.95 	0.88 	0.88 	0.88
# macro	0.95 	0.70 	0.55 	0.52
# not-O	0.95 	0.59 	0.58 	0.58
#
# INFO:Entity level P/R/F1: 0.50/0.53/0.52
#
# INFO:Epoch 5 out of 10
# 5/5 [==============================] - 0s - train loss: 0.3846
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	717.00 	11.00  	21.00  	13.00  	62.00
# ORG    	164.00 	65.00  	27.00  	10.00  	125.00
# LOC    	74.00  	8.00   	392.00 	25.00  	78.00
# MISC   	63.00  	16.00  	9.00   	105.00 	65.00
# O      	81.00  	18.00  	38.00  	3.00   	6976.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.95 	0.65 	0.87 	0.75
# ORG  	0.96 	0.55 	0.17 	0.26
# LOC  	0.97 	0.80 	0.68 	0.74
# MISC 	0.98 	0.67 	0.41 	0.51
# O    	0.95 	0.95 	0.98 	0.97
# micro	0.96 	0.90 	0.90 	0.90
# macro	0.96 	0.73 	0.62 	0.64
# not-O	0.96 	0.69 	0.62 	0.65
#
# INFO:Entity level P/R/F1: 0.60/0.57/0.58
#
# INFO:Epoch 6 out of 10
# 5/5 [==============================] - 0s - train loss: 0.3535
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	720.00 	1.00   	16.00  	20.00  	67.00
# ORG    	172.00 	31.00  	28.00  	27.00  	133.00
# LOC    	55.00  	2.00   	401.00 	43.00  	76.00
# MISC   	53.00  	4.00   	8.00   	132.00 	61.00
# O      	70.00  	7.00   	30.00  	8.00   	7001.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.95 	0.67 	0.87 	0.76
# ORG  	0.96 	0.69 	0.08 	0.14
# LOC  	0.97 	0.83 	0.69 	0.76
# MISC 	0.98 	0.57 	0.51 	0.54
# O    	0.95 	0.95 	0.98 	0.97
# micro	0.96 	0.90 	0.90 	0.90
# macro	0.96 	0.74 	0.63 	0.63
# not-O	0.96 	0.70 	0.63 	0.66
#
# INFO:Entity level P/R/F1: 0.61/0.58/0.59
#
# INFO:Epoch 7 out of 10
# 5/5 [==============================] - 0s - train loss: 0.3257
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	723.00 	1.00   	16.00  	13.00  	71.00
# ORG    	170.00 	40.00  	25.00  	21.00  	135.00
# LOC    	46.00  	1.00   	425.00 	27.00  	78.00
# MISC   	52.00  	3.00   	10.00  	131.00 	62.00
# O      	68.00  	6.00   	24.00  	4.00   	7014.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.95 	0.68 	0.88 	0.77
# ORG  	0.96 	0.78 	0.10 	0.18
# LOC  	0.98 	0.85 	0.74 	0.79
# MISC 	0.98 	0.67 	0.51 	0.58
# O    	0.95 	0.95 	0.99 	0.97
# micro	0.96 	0.91 	0.91 	0.91
# macro	0.96 	0.79 	0.64 	0.66
# not-O	0.97 	0.73 	0.64 	0.68
#
# INFO:Entity level P/R/F1: 0.64/0.59/0.62
#
# INFO:Epoch 8 out of 10
# 5/5 [==============================] - 0s - train loss: 0.3046
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	734.00 	3.00   	20.00  	3.00   	64.00
# ORG    	163.00 	64.00  	30.00  	12.00  	122.00
# LOC    	41.00  	4.00   	457.00 	9.00   	66.00
# MISC   	53.00  	6.00   	22.00  	117.00 	60.00
# O      	64.00  	13.00  	25.00  	0.00   	7014.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.70 	0.89 	0.78
# ORG  	0.96 	0.71 	0.16 	0.27
# LOC  	0.98 	0.82 	0.79 	0.81
# MISC 	0.98 	0.83 	0.45 	0.59
# O    	0.95 	0.96 	0.99 	0.97
# micro	0.97 	0.91 	0.91 	0.91
# macro	0.97 	0.80 	0.66 	0.68
# not-O	0.97 	0.75 	0.67 	0.71
#
# INFO:Entity level P/R/F1: 0.66/0.62/0.64
#
# INFO:Epoch 9 out of 10
# 5/5 [==============================] - 0s - train loss: 0.2945
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	740.00 	5.00   	19.00  	2.00   	58.00
# ORG    	151.00 	87.00  	29.00  	5.00   	119.00
# LOC    	37.00  	8.00   	461.00 	6.00   	65.00
# MISC   	57.00  	10.00  	22.00  	112.00 	57.00
# O      	65.00  	23.00  	17.00  	0.00   	7011.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.70 	0.90 	0.79
# ORG  	0.96 	0.65 	0.22 	0.33
# LOC  	0.98 	0.84 	0.80 	0.82
# MISC 	0.98 	0.90 	0.43 	0.58
# O    	0.96 	0.96 	0.99 	0.97
# micro	0.97 	0.92 	0.92 	0.92
# macro	0.97 	0.81 	0.67 	0.70
# not-O	0.97 	0.75 	0.68 	0.72
#
# INFO:Entity level P/R/F1: 0.67/0.63/0.65
#
# INFO:Epoch 10 out of 10
# 5/5 [==============================] - 0s - train loss: 0.2804
#
# INFO:Evaluating on development data
# 5/5 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu  	PER    	ORG    	LOC    	MISC   	O
# PER    	749.00 	7.00   	17.00  	3.00   	48.00
# ORG    	140.00 	109.00 	25.00  	6.00   	111.00
# LOC    	35.00  	10.00  	464.00 	9.00   	59.00
# MISC   	53.00  	14.00  	15.00  	126.00 	50.00
# O      	57.00  	29.00  	10.00  	0.00   	7020.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.96 	0.72 	0.91 	0.81
# ORG  	0.96 	0.64 	0.28 	0.39
# LOC  	0.98 	0.87 	0.80 	0.84
# MISC 	0.98 	0.88 	0.49 	0.63
# O    	0.96 	0.96 	0.99 	0.97
# micro	0.97 	0.92 	0.92 	0.92
# macro	0.97 	0.82 	0.69 	0.73
# not-O	0.97 	0.77 	0.71 	0.74
#
# INFO:Entity level P/R/F1: 0.69/0.66/0.67
#
# INFO:Model did not crash!
# INFO:Passed!

# %%
# !python q1_window.py train
# Out:
# /Users/KunWuYao/anaconda/lib/python3.5/site-packages/h5py/__init__.py:34: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# INFO:Loading training data...
# INFO:Done. Read 14041 sentences
# INFO:Loading dev data...
# INFO:Done. Read 3250 sentences
# INFO:Built dictionary for 10007 features.
# INFO:Initialized embeddings.
# INFO:Building model...
# INFO:took 1.98 seconds
# 2018-04-19 03:41:48.920376: I tensorflow/core/platform/cpu_feature_guard.cc:137] Your CPU supports instructions that this TensorFlow binary was not compiled to use: SSE4.1 SSE4.2 AVX AVX2 FMA
# INFO:Epoch 1 out of 10
# 100/100 [==============================] - 3s - train loss: 0.3600
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2764.00 	123.00  	88.00   	12.00   	162.00
# ORG     	474.00  	954.00  	273.00  	100.00  	291.00
# LOC     	162.00  	205.00  	1426.00 	97.00   	204.00
# MISC    	165.00  	184.00  	135.00  	597.00  	187.00
# O       	168.00  	130.00  	49.00   	21.00   	42391.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.97 	0.74 	0.88 	0.80
# ORG  	0.97 	0.60 	0.46 	0.52
# LOC  	0.98 	0.72 	0.68 	0.70
# MISC 	0.98 	0.72 	0.47 	0.57
# O    	0.98 	0.98 	0.99 	0.99
# micro	0.97 	0.94 	0.94 	0.94
# macro	0.97 	0.75 	0.70 	0.72
# not-O	0.97 	0.71 	0.67 	0.69
#
# INFO:Entity level P/R/F1: 0.59/0.62/0.61
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 2 out of 10
# 100/100 [==============================] - 3s - train loss: 0.1922
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2835.00 	85.00   	103.00  	18.00   	108.00
# ORG     	364.00  	1230.00 	162.00  	115.00  	221.00
# LOC     	100.00  	237.00  	1538.00 	82.00   	137.00
# MISC    	102.00  	153.00  	94.00   	776.00  	143.00
# O       	102.00  	86.00   	38.00   	41.00   	42492.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.81 	0.90 	0.85
# ORG  	0.97 	0.69 	0.59 	0.63
# LOC  	0.98 	0.79 	0.73 	0.76
# MISC 	0.99 	0.75 	0.61 	0.67
# O    	0.98 	0.99 	0.99 	0.99
# micro	0.98 	0.95 	0.95 	0.95
# macro	0.98 	0.81 	0.77 	0.78
# not-O	0.98 	0.77 	0.74 	0.76
#
# INFO:Entity level P/R/F1: 0.67/0.71/0.69
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 3 out of 10
# 100/100 [==============================] - 3s - train loss: 0.1514
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2885.00 	81.00   	76.00   	22.00   	85.00
# ORG     	274.00  	1386.00 	151.00  	87.00   	194.00
# LOC     	99.00   	215.00  	1634.00 	53.00   	93.00
# MISC    	85.00   	125.00  	92.00   	830.00  	136.00
# O       	92.00   	75.00   	22.00   	43.00   	42527.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.98 	0.84 	0.92 	0.88
# ORG  	0.98 	0.74 	0.66 	0.70
# LOC  	0.98 	0.83 	0.78 	0.80
# MISC 	0.99 	0.80 	0.65 	0.72
# O    	0.99 	0.99 	0.99 	0.99
# micro	0.98 	0.96 	0.96 	0.96
# macro	0.98 	0.84 	0.80 	0.82
# not-O	0.98 	0.81 	0.78 	0.80
#
# INFO:Entity level P/R/F1: 0.71/0.75/0.73
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 4 out of 10
# 100/100 [==============================] - 3s - train loss: 0.1233
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2932.00 	63.00   	56.00   	23.00   	75.00
# ORG     	238.00  	1460.00 	131.00  	82.00   	181.00
# LOC     	85.00   	184.00  	1701.00 	47.00   	77.00
# MISC    	71.00   	93.00   	60.00   	919.00  	125.00
# O       	85.00   	64.00   	17.00   	33.00   	42560.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.86 	0.93 	0.89
# ORG  	0.98 	0.78 	0.70 	0.74
# LOC  	0.99 	0.87 	0.81 	0.84
# MISC 	0.99 	0.83 	0.72 	0.77
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.87 	0.83 	0.85
# not-O	0.99 	0.84 	0.82 	0.83
#
# INFO:Entity level P/R/F1: 0.75/0.78/0.77
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 5 out of 10
# 100/100 [==============================] - 3s - train loss: 0.1018
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2895.00 	56.00   	71.00   	21.00   	106.00
# ORG     	180.00  	1545.00 	125.00  	64.00   	178.00
# LOC     	57.00   	156.00  	1767.00 	31.00   	83.00
# MISC    	59.00   	72.00   	63.00   	944.00  	130.00
# O       	56.00   	52.00   	21.00   	34.00   	42596.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.89 	0.92 	0.91
# ORG  	0.98 	0.82 	0.74 	0.78
# LOC  	0.99 	0.86 	0.84 	0.85
# MISC 	0.99 	0.86 	0.74 	0.80
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.89 	0.85 	0.87
# not-O	0.99 	0.86 	0.83 	0.85
#
# INFO:Entity level P/R/F1: 0.78/0.80/0.79
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 6 out of 10
# 100/100 [==============================] - 3s - train loss: 0.0863
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2895.00 	75.00   	77.00   	17.00   	85.00
# ORG     	160.00  	1589.00 	132.00  	55.00   	156.00
# LOC     	52.00   	133.00  	1824.00 	16.00   	69.00
# MISC    	58.00   	73.00   	65.00   	952.00  	120.00
# O       	54.00   	53.00   	20.00   	32.00   	42600.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.90 	0.92 	0.91
# ORG  	0.98 	0.83 	0.76 	0.79
# LOC  	0.99 	0.86 	0.87 	0.87
# MISC 	0.99 	0.89 	0.75 	0.81
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.89 	0.86 	0.87
# not-O	0.99 	0.87 	0.84 	0.86
#
# INFO:Entity level P/R/F1: 0.79/0.82/0.80
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 7 out of 10
# 100/100 [==============================] - 3s - train loss: 0.0734
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2942.00 	35.00   	69.00   	23.00   	80.00
# ORG     	160.00  	1576.00 	135.00  	63.00   	158.00
# LOC     	52.00   	99.00   	1859.00 	22.00   	62.00
# MISC    	47.00   	50.00   	64.00   	981.00  	126.00
# O       	45.00   	43.00   	19.00   	29.00   	42623.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.91 	0.93 	0.92
# ORG  	0.99 	0.87 	0.75 	0.81
# LOC  	0.99 	0.87 	0.89 	0.88
# MISC 	0.99 	0.88 	0.77 	0.82
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.90 	0.87 	0.88
# not-O	0.99 	0.89 	0.86 	0.87
#
# INFO:Entity level P/R/F1: 0.81/0.83/0.82
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 8 out of 10
# 100/100 [==============================] - 3s - train loss: 0.0650
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 0s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2927.00 	51.00   	73.00   	19.00   	79.00
# ORG     	140.00  	1644.00 	115.00  	54.00   	139.00
# LOC     	45.00   	106.00  	1866.00 	18.00   	59.00
# MISC    	43.00   	62.00   	54.00   	991.00  	118.00
# O       	45.00   	47.00   	20.00   	31.00   	42616.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.91 	0.93 	0.92
# ORG  	0.99 	0.86 	0.79 	0.82
# LOC  	0.99 	0.88 	0.89 	0.88
# MISC 	0.99 	0.89 	0.78 	0.83
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.91 	0.88 	0.89
# not-O	0.99 	0.89 	0.86 	0.88
#
# INFO:Entity level P/R/F1: 0.82/0.84/0.83
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
# INFO:Epoch 9 out of 10
# 100/100 [==============================] - 3s - train loss: 0.0581
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 1s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2944.00 	41.00   	82.00   	21.00   	61.00
# ORG     	150.00  	1627.00 	119.00  	64.00   	132.00
# LOC     	51.00   	90.00   	1881.00 	25.00   	47.00
# MISC    	45.00   	53.00   	57.00   	997.00  	116.00
# O       	50.00   	47.00   	20.00   	25.00   	42617.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.91 	0.93 	0.92
# ORG  	0.99 	0.88 	0.78 	0.82
# LOC  	0.99 	0.87 	0.90 	0.88
# MISC 	0.99 	0.88 	0.79 	0.83
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.97 	0.97 	0.97
# macro	0.99 	0.91 	0.88 	0.89
# not-O	0.99 	0.89 	0.87 	0.88
#
# INFO:Entity level P/R/F1: 0.81/0.85/0.83
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# INFO:Epoch 10 out of 10
# 100/100 [==============================] - 5s - train loss: 0.0524
#
# INFO:Evaluating on development data
# 26/26 [==============================] - 1s
# DEBUG:Token-level confusion matrix:
# go\gu   	PER     	ORG     	LOC     	MISC    	O
# PER     	2949.00 	36.00   	80.00   	19.00   	65.00
# ORG     	142.00  	1644.00 	119.00  	68.00   	119.00
# LOC     	51.00   	93.00   	1880.00 	26.00   	44.00
# MISC    	45.00   	50.00   	46.00   	1020.00 	107.00
# O       	49.00   	48.00   	16.00   	34.00   	42612.00
#
# DEBUG:Token-level scores:
# label	acc  	prec 	rec  	f1
# PER  	0.99 	0.91 	0.94 	0.92
# ORG  	0.99 	0.88 	0.79 	0.83
# LOC  	0.99 	0.88 	0.90 	0.89
# MISC 	0.99 	0.87 	0.80 	0.84
# O    	0.99 	0.99 	1.00 	0.99
# micro	0.99 	0.98 	0.98 	0.98
# macro	0.99 	0.91 	0.88 	0.89
# not-O	0.99 	0.89 	0.87 	0.88
#
# INFO:Entity level P/R/F1: 0.81/0.85/0.83
# INFO:New best score! Saving model in results/window/20180419_034142/model.weights
#
# 26/26 [==============================] - 1s
